# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

irisdf = pd.read_csv('Iris_data.csv')

# %%
irisdf.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Mvdf = pd.read_csv('Movie_cls.csv')
Mvdf.head(10)
# Out:
#   Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0           201.264               59.62               462.0  36.524.125
# 1           205.462               69.14               531.0  35.668.655
# 2           205.458               69.14               531.0  39.912.675
# 3           206.474               59.36               542.0    38873.89
# 4            21.381               59.36               542.0  39.701.585
# 5            20.597               59.36               542.0    35718.65
# 6           217.658               70.74               476.0    33396.66
# 7            22.891               70.74               476.0    34285.46
# 8           242.248               70.74               476.0  31.280.205
# 9           234.008               70.74               476.0    33352.22
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# ...

# %%
irisdf.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
irisdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
Mvdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    object
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    object
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
#Ketika di Transpose
Mvdf.describe().T
# Out:
#                      count           mean           std         min  \
# Production expense   506.0      77.273557     13.720706      55.920
# Multiplex coverage   506.0     382.999097    192.003636       0.230
# Movie_length         506.0     142.074901     28.148861      76.400
# Lead_ Actor_Rating   506.0       8.014002      1.054266       3.840
# Lead_Actress_rating  506.0       8.185613      1.054290       4.035
# Director_rating      506.0       8.019664      1.059899       3.840
# Producer_rating      506.0       8.190514      1.049601       4.030
# Critic_rating        506.0       7.810870      0.659699       6.600
# Trailer_views        506.0  449860.715415  68917.763145  212912.000
# Time_taken           494.0     157.391498     31.295161       0.000
# Twitter_hastags      506.0     260.832095    104.779133     201.152
# Avg_age_actors       506.0      39.181818     12.513697       3.000
# Num_multiplex        506.0     545.043478    106.332889     333.000
# ...

# %%
#Tanpa di transpose
Mvdf.describe()
# Out:
#        Production expense  Multiplex coverage  Movie_length  \
# count          506.000000          506.000000    506.000000
# mean            77.273557          382.999097    142.074901
# std             13.720706          192.003636     28.148861
# min             55.920000            0.230000     76.400000
# 25%             65.380000          307.000000    118.525000
# 50%             74.380000          453.000000    151.000000
# 75%             91.200000          536.000000    167.575000
# max            110.480000          615.000000    173.500000
#
#        Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# count          506.000000           506.000000       506.000000
# mean             8.014002             8.185613         8.019664
# std              1.054266             1.054290         1.059899
# min              3.840000             4.035000         3.840000
# 25%              7.316250             7.503750         7.296250
# ...

# %%
#Mengecek Missing Value
Mvdf.isna()
# Out:
#      Marketing expense  Production expense  Multiplex coverage  Budget  \
# 0                False               False               False   False
# 1                False               False               False   False
# 2                False               False               False   False
# 3                False               False               False   False
# 4                False               False               False   False
# ..                 ...                 ...                 ...     ...
# 501              False               False               False   False
# 502              False               False               False   False
# 503              False               False               False   False
# 504              False               False               False   False
# 505              False               False               False   False
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
#Melihat jumlah yang NA
Mvdf.isna().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
Mvdf.isnull().sum() #Sama aja cuma lebih keren wkwkkw
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
Mvdf.shape #Ukuran baris dan kolom
# Out:
# (506, 19)

# %%
Mvdf.dtypes #Melihat type data
# Out:
# Marketing expense       object
# Production expense     float64
# Multiplex coverage     float64
# Budget                  object
# Movie_length           float64
# Lead_ Actor_Rating     float64
# Lead_Actress_rating    float64
# Director_rating        float64
# Producer_rating        float64
# Critic_rating          float64
# Trailer_views            int64
# 3D_available            object
# Time_taken             float64
# Twitter_hastags        float64
# Genre                   object
# Avg_age_actors           int64
# Num_multiplex            int64
# Collection               int64
# Start_Tech_Oscar         int64
# dtype: object

# %%
Mvdf.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Length: 506, dtype: bool

# %%
Mvdf.duplicated().sum() #Ketika dijumlahkan
# Out:
# np.int64(0)

# %%
(Mvdf.isna().sum()/len(Mvdf))*100 #Persentase NA
# Out:
# Marketing expense      0.0
# Production expense     0.0
# Multiplex coverage     0.0
# Budget                 0.0
# Movie_length           0.0
# Lead_ Actor_Rating     0.0
# Lead_Actress_rating    0.0
# Director_rating        0.0
# Producer_rating        0.0
# Critic_rating          0.0
# Trailer_views          0.0
# 3D_available           0.0
# Time_taken             0.0
# Twitter_hastags        0.0
# Genre                  0.0
# Avg_age_actors         0.0
# Num_multiplex          0.0
# Collection             0.0
# Start_Tech_Oscar       0.0
# dtype: float64

# %%
Mvdf.dropna(inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Mvdf.dropna(inplace=False)
#
# NameError: name 'Mvdf' is not defined

# %%
Mvdf.dropna(inplace=True)

# %%
    Mvdf.isna().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %%
Mv = Mvdf.to_excel('Movie_cls.xlsx',index = False) #index false, agar index pada File tidak diikutkan.

# %%
Mv = pd.read_excel('Movie_cls.xlsx')
Mv.head()
# Out:
#   Marketing expense  Production expense  Multiplex coverage      Budget  \
# 0           201.264               59.62               462.0  36.524.125
# 1           205.462               69.14               531.0  35.668.655
# 2           205.458               69.14               531.0  39.912.675
# 3           206.474               59.36               542.0    38873.89
# 4            21.381               59.36               542.0  39.701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
iris_filename = "Iris_data.csv"
iris = pd.read_csv(iris_filename, sep=",",
                   decimal=".", header=None,
                   names= ["sepal_length",
                    "sepal_width",
                    "petal_length",
                    "petal_width",
                    "target"])
iris
# Out:
#       sepal_length   sepal_width   petal_length   petal_width          target
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1             5.10          3.50           1.40          0.20     Iris-setosa
# 2             4.90          3.00           1.40          0.20     Iris-setosa
# 3             4.70          3.20           1.30          0.20     Iris-setosa
# 4             4.60          3.10           1.50          0.20     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146           6.70          3.00           5.20          2.30  Iris-virginica
# 147           6.30          2.50           5.00          1.90  Iris-virginica
# 148           6.50          3.00           5.20          2.00  Iris-virginica
# 149           6.20          3.40           5.40          2.30  Iris-virginica
# 150           5.90          3.00           5.10          1.80  Iris-virginica
#
# [151 rows x 5 columns]

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'], dtype='object')

# %%
iris['target']
# Out:
# Id            Species
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: target, Length: 151, dtype: object

# %%
iris.target
# Out:
# Id            Species
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: target, Length: 151, dtype: object

# %%
iris.set_index("target", inplace = True)
iris.head()
# Out:
#               sepal_length   sepal_width   petal_length   petal_width
# target
# Species      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Iris-setosa           5.10          3.50           1.40          0.20
# Iris-setosa           4.90          3.00           1.40          0.20
# Iris-setosa           4.70          3.20           1.30          0.20
# Iris-setosa           4.60          3.10           1.50          0.20

# %%
iris.reset_index(drop = True, inplace = True)
iris.head()
# Out:
#     sepal_length   sepal_width   petal_length   petal_width
# 0  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1           5.10          3.50           1.40          0.20
# 2           4.90          3.00           1.40          0.20
# 3           4.70          3.20           1.30          0.20
# 4           4.60          3.10           1.50          0.20

# %%
iris_filename = "Iris_data.csv"
iris = pd.read_csv(iris_filename)

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris["sepal_ratio"] = iris["SepalLengthCm"]/iris["SepalWidthCm"]
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_ratio
# 0     1.457143
# 1     1.633333
# 2     1.468750
# 3     1.483871
# 4     1.388889

# %%
iris["petal_area"] = iris.apply(lambda row: row["PetalLengthCm"] * row["PetalWidthCm"], axis = 1)
#axis = 0 adalah baris
#axis = 1 adalah kolom
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_ratio  petal_area
# 0     1.457143        0.28
# 1     1.633333        0.28
# 2     1.468750        0.26
# 3     1.483871        0.30
# 4     1.388889        0.28

# %%
#Handling missing value, dapat di drop atau diimputasi
#Normalisasi data
